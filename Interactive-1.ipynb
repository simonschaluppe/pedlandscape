# %% [markdown]
# Connected to base (Python 3.11.4)

# %%
import pandas as pd
# Definition der korrekten Bereiche (basierend auf Benutzerinfo)
meta_rows = range(7, 14)             # Projekt-Metadaten: Zeile 8–14 (Index 7–13)
project_kw_rows = range(13, 76)      # Projekt-Keywords: Zeile 14–76 (Index 13–75)
deliverable_meta_rows = 3           # Immer 3 Metazeilen pro Deliverable
deliverable_kw_rows = 61            # Danach 61 Zeilen mit Keywords
first_deliverable_start = 76        # Erste Deliverable beginnt in Zeile 77 (Index 76)

# Extraktions-Funktion
def extract_projects_for_visualization(df):
    projects_data = []
    for col in df.columns[1:]:  # Spalte 0 enthält Fragen
        project = {}

        # Projekt-Metadaten
        meta_keys = df.iloc[meta_rows, 0].values
        meta_vals = df.iloc[meta_rows, col].values
        project["name"] = df.iloc[7, col]  # [Project Name]
        project["acronym"] = df.iloc[8, col]  # [Project Acronym]
        project["metadata"] = dict(zip(meta_keys, meta_vals))

        # Projekt-Keywords
        kw_labels = df.iloc[project_kw_rows, 0].values
        kw_values = df.iloc[project_kw_rows, col].fillna("").astype(str).values
        project_keywords = [kw for kw, val in zip(kw_labels, kw_values) if val.strip() not in ["", "0", "nan"]]
        project["keywords"] = project_keywords

        # Deliverables
        deliverables = []
        row = first_deliverable_start
        while row + deliverable_meta_rows + deliverable_kw_rows <= df.shape[0]:
            # Metadaten
            d_meta_keys = df.iloc[row:row+deliverable_meta_rows, 0].values
            d_meta_vals = df.iloc[row:row+deliverable_meta_rows, col].values
            if pd.isna(d_meta_vals[0]) or d_meta_vals[0] == "":
                break  # kein weiteres Deliverable
            d_metadata = dict(zip(d_meta_keys, d_meta_vals))

            # Keywords
            d_kw_labels = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, 0].values
            d_kw_values = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, col].fillna("").astype(str).values
            d_keywords = [kw for kw, val in zip(d_kw_labels, d_kw_values) if val.strip() not in ["", "0", "nan"]]

            deliverables.append({
                "metadata": d_metadata,
                "keywords": d_keywords
            })

            row += deliverable_meta_rows + deliverable_kw_rows  # Nächster Block

        project["deliverables"] = deliverables
        projects_data.append(project)

    return projects_data



if __name__ == "__main__":
    # Anwendung der Funktion
    df = pd.read_excel("results2.xlsx")
    structured_projects = extract_projects_for_visualization(df)

    # Vorschau
    structured_projects[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\Simon Schneider\OneDrive\PhD\8 PED Landscape\parse.py:61
#      58 if __name__ == "__main__":
#      59     # Anwendung der Funktion
#      60     df = pd.read_excel("results2.xlsx")
# ---> 61     structured_projects = extract_projects_for_visualization(df)
#      63     # Vorschau
#      64     structured_projects[0]
#
# File c:\Users\Simon Schneider\OneDrive\PhD\8 PED Landscape\parse.py:17
#      15 # Projekt-Metadaten
#      16 meta_keys = df.iloc[meta_rows, 0].values
# ---> 17 meta_vals = df.iloc[meta_rows, col].values
#      18 project["name"] = df.iloc[7, col]  # [Project Name]
#      19 project["acronym"] = df.iloc[8, col]  # [Project Acronym]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1592, in _iLocIndexer._validate_key(self, key, axis)
#    1590     return
#    1591 elif is_integer(key):
# -> 1592     self._validate_integer(key, axis)
#    1593 elif isinstance(key, tuple):
#    1594     # a tuple should already have been caught by this point
#    1595     # so don't treat a tuple as a valid indexer
#    1596     raise IndexingError("Too many indexers")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
structured_projects
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 structured_projects
#
# NameError: name 'structured_projects' is not defined

# %%
import pandas as pd
# Definition der korrekten Bereiche (basierend auf Benutzerinfo)
meta_rows = range(7, 14)             # Projekt-Metadaten: Zeile 8–14 (Index 7–13)
project_kw_rows = range(13, 76)      # Projekt-Keywords: Zeile 14–76 (Index 13–75)
deliverable_meta_rows = 3           # Immer 3 Metazeilen pro Deliverable
deliverable_kw_rows = 61            # Danach 61 Zeilen mit Keywords
first_deliverable_start = 76        # Erste Deliverable beginnt in Zeile 77 (Index 76)

# Extraktions-Funktion
def extract_projects_for_visualization(df):
    projects_data = []
    for col in df.columns[1:]:  # Spalte 0 enthält Fragen
        project = {}

        # Projekt-Metadaten
        meta_keys = df.iloc[meta_rows, 0].values
        meta_vals = df.iloc[meta_rows, col].values
        project["name"] = df.iloc[7, col]  # [Project Name]
        project["acronym"] = df.iloc[8, col]  # [Project Acronym]
        project["metadata"] = dict(zip(meta_keys, meta_vals))

        # Projekt-Keywords
        kw_labels = df.iloc[project_kw_rows, 0].values
        kw_values = df.iloc[project_kw_rows, col].fillna("").astype(str).values
        project_keywords = [kw for kw, val in zip(kw_labels, kw_values) if val.strip() not in ["", "0", "nan"]]
        project["keywords"] = project_keywords

        # Deliverables
        deliverables = []
        row = first_deliverable_start
        while row + deliverable_meta_rows + deliverable_kw_rows <= df.shape[0]:
            # Metadaten
            d_meta_keys = df.iloc[row:row+deliverable_meta_rows, 0].values
            d_meta_vals = df.iloc[row:row+deliverable_meta_rows, col].values
            if pd.isna(d_meta_vals[0]) or d_meta_vals[0] == "":
                break  # kein weiteres Deliverable
            d_metadata = dict(zip(d_meta_keys, d_meta_vals))

            # Keywords
            d_kw_labels = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, 0].values
            d_kw_values = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, col].fillna("").astype(str).values
            d_keywords = [kw for kw, val in zip(d_kw_labels, d_kw_values) if val.strip() not in ["", "0", "nan"]]

            deliverables.append({
                "metadata": d_metadata,
                "keywords": d_keywords
            })

            row += deliverable_meta_rows + deliverable_kw_rows  # Nächster Block

        project["deliverables"] = deliverables
        projects_data.append(project)

    return projects_data



if __name__ == "__main__":
    # Anwendung der Funktion
    df = pd.read_excel("results2.xlsx")
    structured_projects = extract_projects_for_visualization(df)

    # Vorschau
    structured_projects[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\Simon Schneider\OneDrive\PhD\8 PED Landscape\parse.py:61
#      58 if __name__ == "__main__":
#      59     # Anwendung der Funktion
#      60     df = pd.read_excel("results2.xlsx")
# ---> 61     structured_projects = extract_projects_for_visualization(df)
#      63     # Vorschau
#      64     structured_projects[0]
#
# File c:\Users\Simon Schneider\OneDrive\PhD\8 PED Landscape\parse.py:17
#      15 # Projekt-Metadaten
#      16 meta_keys = df.iloc[meta_rows, 0].values
# ---> 17 meta_vals = df.iloc[meta_rows, col].values
#      18 project["name"] = df.iloc[7, col]  # [Project Name]
#      19 project["acronym"] = df.iloc[8, col]  # [Project Acronym]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1592, in _iLocIndexer._validate_key(self, key, axis)
#    1590     return
#    1591 elif is_integer(key):
# -> 1592     self._validate_integer(key, axis)
#    1593 elif isinstance(key, tuple):
#    1594     # a tuple should already have been caught by this point
#    1595     # so don't treat a tuple as a valid indexer
#    1596     raise IndexingError("Too many indexers")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
df
# Out:
#                                            Response ID                    1  \
# 0                                       Date submitted  2025-03-12 09:00:30
# 1                                            Last page                   11
# 2                                       Start language                   en
# 3                                                 Seed           1974936967
# 4                                         Date started  2025-03-12 08:09:49
# ..                                                 ...                  ...
# 710       TECHNOLOGICAL Keywords    [Infstrastructure]                   No
# 711  TECHNOLOGICAL Keywords    [Multi-commodity ene...                   No
# 712  OTHER  If none of the keywords above apply, yo...                  NaN
# 713  OTHER  If none of the keywords above apply, yo...                  NaN
# 714  OTHER  If none of the keywords above apply, yo...                  NaN
#
#                        2                    4                   10  \
# 0    2025-03-17 18:52:08  2025-03-20 14:31:38  1980-01-01 00:00:00
# 1                     11                   11                   11
# 2                     en                   en                   en
# 3              466345074            421354583           1593263357
# 4    2025-03-17 18:34:04  2025-03-20 14:15:16                  NaN
# ..                   ...                  ...                  ...
# 710                   No                   No                   No
# 711                   No                   No                   No
# 712                  NaN                  NaN                  NaN
# 713                  NaN                  NaN                  NaN
# 714                  NaN                  NaN                  NaN
#
#                       11                   17                   18  \
# 0    1980-01-01 00:00:00  1980-01-01 00:00:00  1980-01-01 00:00:00
# 1                     11                   11                   11
# 2                     en                   en                   en
# 3              644478860           2040776747           2071707710
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 710                   No                   No                   No
# 711                   No                   No                   No
# 712                  NaN                  NaN                  NaN
# 713                  NaN                  NaN                  NaN
# 714                  NaN                  NaN                  NaN
#
#                       29
# 0    1980-01-01 00:00:00
# 1                     11
# 2                     en
# 3             1377982420
# 4                    NaN
# ..                   ...
# 710                   No
# 711                   No
# 712                  NaN
# 713                  NaN
# 714                  NaN
#
# [715 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Response ID', 1, 2, 4, 10, 11, 17, 18, 29], dtype='object')

# %%
df.iloc[range(7,14), 1]
# Out:
# 7                                               PED-ACT
# 8                                  https://ped-act.com/
# 9                                                 10/22
# 10                                              08/2025
# 11    xza@du.se   (project coordinator  Xing Xing Zh...
# 12    Positive Energy District (PED) is graded as an...
# 13                                                   No
# Name: 1, dtype: object

# %%
a = df.iloc[range(7,14), 1]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df.iloc[range(7,14), 0]
# Out:
# 7                                     [Project Acronym]
# 8                           [URL to Project ressources]
# 9                                  [Project started in]
# 10                                   [Project duration]
# 11    [Contact (optional email for inquiries about r...
# 12                       Project description (Optional)
# 13                        ECONOMIC Keywords    [Market]
# Name: Response ID, dtype: object

# %%
a = df.iloc[range(7,14), 18]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a = df.iloc[range(7,14), 18]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1592, in _iLocIndexer._validate_key(self, key, axis)
#    1590     return
#    1591 elif is_integer(key):
# -> 1592     self._validate_integer(key, axis)
#    1593 elif isinstance(key, tuple):
#    1594     # a tuple should already have been caught by this point
#    1595     # so don't treat a tuple as a valid indexer
#    1596     raise IndexingError("Too many indexers")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
import pandas as pd
# Definition der korrekten Bereiche (basierend auf Benutzerinfo)
meta_rows = range(7, 14)             # Projekt-Metadaten: Zeile 8–14 (Index 7–13)
project_kw_rows = range(13, 76)      # Projekt-Keywords: Zeile 14–76 (Index 13–75)
deliverable_meta_rows = 3           # Immer 3 Metazeilen pro Deliverable
deliverable_kw_rows = 61            # Danach 61 Zeilen mit Keywords
first_deliverable_start = 76        # Erste Deliverable beginnt in Zeile 77 (Index 76)

# Extraktions-Funktion
def extract_projects_for_visualization(df):
    projects_data = []
    for col, colname in enumerate(df.columns[1:]):  # Spalte 0 enthält Fragen
        col+=1
        project = {}

        # Projekt-Metadaten
        meta_keys = df.iloc[meta_rows, 0].values
        meta_vals = df.iloc[meta_rows, col].values
        project["name"] = df.iloc[7, col]  # [Project Name]
        project["acronym"] = df.iloc[8, col]  # [Project Acronym]
        project["metadata"] = dict(zip(meta_keys, meta_vals))

        # Projekt-Keywords
        kw_labels = df.iloc[project_kw_rows, 0].values
        kw_values = df.iloc[project_kw_rows, col].fillna("").astype(str).values
        project_keywords = [kw for kw, val in zip(kw_labels, kw_values) if val.strip() not in ["", "0", "nan"]]
        project["keywords"] = project_keywords

        # Deliverables
        deliverables = []
        row = first_deliverable_start
        while row + deliverable_meta_rows + deliverable_kw_rows <= df.shape[0]:
            # Metadaten
            d_meta_keys = df.iloc[row:row+deliverable_meta_rows, 0].values
            d_meta_vals = df.iloc[row:row+deliverable_meta_rows, col].values
            if pd.isna(d_meta_vals[0]) or d_meta_vals[0] == "":
                break  # kein weiteres Deliverable
            d_metadata = dict(zip(d_meta_keys, d_meta_vals))

            # Keywords
            d_kw_labels = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, 0].values
            d_kw_values = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, col].fillna("").astype(str).values
            d_keywords = [kw for kw, val in zip(d_kw_labels, d_kw_values) if val.strip() not in ["", "0", "nan"]]

            deliverables.append({
                "metadata": d_metadata,
                "keywords": d_keywords
            })

            row += deliverable_meta_rows + deliverable_kw_rows  # Nächster Block

        project["deliverables"] = deliverables
        projects_data.append(project)

    return projects_data



if __name__ == "__main__":
    # Anwendung der Funktion
    df = pd.read_excel("results2.xlsx")
    structured_projects = extract_projects_for_visualization(df)

    # Vorschau
    structured_projects[0]

# %%
import pandas as pd
# Definition der korrekten Bereiche (basierend auf Benutzerinfo)
meta_rows = range(7, 14)             # Projekt-Metadaten: Zeile 8–14 (Index 7–13)
project_kw_rows = range(13, 76)      # Projekt-Keywords: Zeile 14–76 (Index 13–75)
deliverable_meta_rows = 3           # Immer 3 Metazeilen pro Deliverable
deliverable_kw_rows = 61            # Danach 61 Zeilen mit Keywords
first_deliverable_start = 76        # Erste Deliverable beginnt in Zeile 77 (Index 76)

# Extraktions-Funktion
def extract_projects_for_visualization(df):
    projects_data = []
    for col, colname in enumerate(df.columns[1:]):  # Spalte 0 enthält Fragen
        col+=1
        project = {}

        # Projekt-Metadaten
        meta_keys = df.iloc[meta_rows, 0].values
        meta_vals = df.iloc[meta_rows, col].values
        project["name"] = df.iloc[7, col]  # [Project Name]
        project["acronym"] = df.iloc[8, col]  # [Project Acronym]
        project["metadata"] = dict(zip(meta_keys, meta_vals))

        # Projekt-Keywords
        kw_labels = df.iloc[project_kw_rows, 0].values
        kw_values = df.iloc[project_kw_rows, col].fillna("").astype(str).values
        project_keywords = [kw for kw, val in zip(kw_labels, kw_values) if val.strip() not in ["", "0", "nan"]]
        project["keywords"] = project_keywords

        # Deliverables
        deliverables = []
        row = first_deliverable_start
        while row + deliverable_meta_rows + deliverable_kw_rows <= df.shape[0]:
            # Metadaten
            d_meta_keys = df.iloc[row:row+deliverable_meta_rows, 0].values
            d_meta_vals = df.iloc[row:row+deliverable_meta_rows, col].values
            if pd.isna(d_meta_vals[0]) or d_meta_vals[0] == "":
                break  # kein weiteres Deliverable
            d_metadata = dict(zip(d_meta_keys, d_meta_vals))

            # Keywords
            d_kw_labels = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, 0].values
            d_kw_values = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, col].fillna("").astype(str).values
            d_keywords = [kw for kw, val in zip(d_kw_labels, d_kw_values) if val.strip() not in ["", "0", "nan"]]

            deliverables.append({
                "metadata": d_metadata,
                "keywords": d_keywords
            })

            row += deliverable_meta_rows + deliverable_kw_rows  # Nächster Block

        project["deliverables"] = deliverables
        projects_data.append(project)

    return projects_data



if __name__ == "__main__":
    # Anwendung der Funktion
    df = pd.read_excel("results2.xlsx")
    structured_projects = extract_projects_for_visualization(df)

    # Vorschau
    structured_projects[0]

# %%
import pandas as pd
# Definition der korrekten Bereiche (basierend auf Benutzerinfo)
meta_rows = range(7, 14)             # Projekt-Metadaten: Zeile 8–14 (Index 7–13)
project_kw_rows = range(13, 76)      # Projekt-Keywords: Zeile 14–76 (Index 13–75)
deliverable_meta_rows = 3           # Immer 3 Metazeilen pro Deliverable
deliverable_kw_rows = 61            # Danach 61 Zeilen mit Keywords
first_deliverable_start = 76        # Erste Deliverable beginnt in Zeile 77 (Index 76)

# Extraktions-Funktion
def extract_projects_for_visualization(df):
    projects_data = []
    for col, colname in enumerate(df.columns[1:]):  # Spalte 0 enthält Fragen
        col+=1
        project = {}

        # Projekt-Metadaten
        meta_keys = df.iloc[meta_rows, 0].values
        meta_vals = df.iloc[meta_rows, col].values
        project["name"] = df.iloc[7, col]  # [Project Name]
        project["acronym"] = df.iloc[8, col]  # [Project Acronym]
        project["metadata"] = dict(zip(meta_keys, meta_vals))

        # Projekt-Keywords
        kw_labels = df.iloc[project_kw_rows, 0].values
        kw_values = df.iloc[project_kw_rows, col].fillna("").astype(str).values
        project_keywords = [kw for kw, val in zip(kw_labels, kw_values) if val.strip() not in ["", "0", "nan"]]
        project["keywords"] = project_keywords

        # Deliverables
        deliverables = []
        row = first_deliverable_start
        while row + deliverable_meta_rows + deliverable_kw_rows <= df.shape[0]:
            # Metadaten
            d_meta_keys = df.iloc[row:row+deliverable_meta_rows, 0].values
            d_meta_vals = df.iloc[row:row+deliverable_meta_rows, col].values
            if pd.isna(d_meta_vals[0]) or d_meta_vals[0] == "":
                break  # kein weiteres Deliverable
            d_metadata = dict(zip(d_meta_keys, d_meta_vals))

            # Keywords
            d_kw_labels = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, 0].values
            d_kw_values = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, col].fillna("").astype(str).values
            d_keywords = [kw for kw, val in zip(d_kw_labels, d_kw_values) if val.strip() not in ["", "0", "nan"]]

            deliverables.append({
                "metadata": d_metadata,
                "keywords": d_keywords
            })

            row += deliverable_meta_rows + deliverable_kw_rows  # Nächster Block

        project["deliverables"] = deliverables
        projects_data.append(project)

    return projects_data



if __name__ == "__main__":
    # Anwendung der Funktion
    df = pd.read_excel("results2.xlsx")
    p = extract_projects_for_visualization(df)

    # Vorschau
    p[0]

# %%
p
# Out:
# [{'name': 'PED-ACT',
#   'acronym': 'https://ped-act.com/',
#   'metadata': {'[Project Acronym]': 'PED-ACT',
#    '[URL to Project ressources]': 'https://ped-act.com/',
#    '[Project started in]': '10/22',
#    '[Project duration]': '08/2025',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': 'xza@du.se   (project coordinator  Xing Xing Zhang)',
#    'Project description (Optional)': 'Positive Energy District (PED) is graded as an essential component towards climate neutrality and smart cities. The development of PED brings great needs in new processes and the related cooperation among stakeholders. This project (‘PED-ACT’) aims to optimise the process iteratively of PED development for enhanced stakeholder cooperation and reinforced decision-making.\nPED-ACT extracts the main characterization of PEDs automatically by machine learning approaches, through standardisation of the common database for existing PEDs, by focusing on Sweden, Turkey, and Austria. The digital PED references are then generated, based on a multi-criteria characterization matrix, by auto-matching the development needs/priorities from different stakeholders during bilateral learning and co-design processes among four specific cities (Borlänge, Umea, Karsiyaka-Izmir, Ankara) and a county (Lower Austria). PED-ACT finally evaluates the feasibility of these digital PED references to further develop the replication/upscaling plans, towards ‘climate-neutrality and smart cities’ goals.\nPED-ACT deeply learns a wealth of information from the existing PEDs and then maps the practical needs for PED development in local contexts iteratively. It leads to concrete cooperation from the outset with support of data and involvement of stakeholders. The project results will reinforce decision-making of PEDs and support public administrators/local stakeholders in the new pathways and development.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Market]',
#    'ECONOMIC Keywords    [Financial Strategies]',
#    'ECONOMIC Keywords    [Circular Economy]',
#    'ECONOMIC Keywords    [Cost Analysis]',
#    'ECONOMIC Keywords    [Affordability]',
#    'ECONOMIC Keywords    [Support and Information]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'ECONOMIC Keywords    [Incentives]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Multi-level Legislation]',
#    'LEGAL Keywords    [Urban Landuse ]',
#    'LEGAL Keywords    [District Regulation]',
#    'LEGAL Keywords    [Participative Instruments]',
#    'LEGAL Keywords    [Energy Communities]',
#    'LEGAL Keywords    [Energy market structures]',
#    'LEGAL Keywords    [Innovative Institutional Change]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Narrative& Storytellung]',
#    'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#    'SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'SOCIAL Keywords    [Social Justice & Equity]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SOCIAL Keywords    [Cultural context]',
#    'SOCIAL Keywords    [Heritage]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'SPATIAL Keywords    [Governance Framework]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'PROCESSES & METHODS Keywords    [Scalability]',
#    'ENVIRONMENTAL Keywords    [Circularity]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'ENVIRONMENTAL Keywords    [Embodied energy]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Landscape]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'ENVIRONMENTAL Keywords    [Resilience]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Political Engagement]',
#    'POLITICAL Keywords    [Power Analysis]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Distributive Implications]',
#    'POLITICAL Keywords    [Regulation and Subsidies]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]',
#    'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#    'TECHNOLOGICAL Keywords    [Infrastructure]',
#    'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#    'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 1]',
#    'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 2]',
#    'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]'],
#   'deliverables': []},
#  {'name': 'PROPEL',
#   'acronym': 'https://sites.google.com/view/propel-ped/home-page?authuser=0',
#   'metadata': {'[Project Acronym]': 'PROPEL',
#    '[URL to Project ressources]': 'https://sites.google.com/view/propel-ped/home-page?authuser=0',
#    '[Project started in]': 2022,
#    '[Project duration]': '3 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': 'nicolas.caballero@eurac.edu',
#    'Project description (Optional)': 'The overall project goal is to demonstrate and assess methods to improve viability in PEDs by technological and societal innovation in urban agriculture, green/waste management, and transport. Including new innovative components into PEDs enables resilient energy supply to the system of urban systems, including urban-rural\nrelationships and transports within this system, by developing ethic business models based on circularity of resources and social innovation. The innovative edge is the inclusion of innovative PED components and improving possibilities for off-grid operation to increase the robustness and viability of PEDs, utilizing viable business models and innovative types of energy carriers via recycling of energy in the food-feed system, biogas and including transports in the PED system of systems. The innovative components that are included into PEDs are other types of energy carriers, via the food system of an urban system, while providing ecosystem services (e.g. closing nutrient cycles ensuring food security, mitigating climate change), improving the liveability in urban areas, and harmonize the urban-rural relationship in Sweden, Turkey and Italy.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Market]',
#    'ECONOMIC Keywords    [Financial Strategies]',
#    'ECONOMIC Keywords    [Circular Economy]',
#    'ECONOMIC Keywords    [Cost Analysis]',
#    'ECONOMIC Keywords    [Affordability]',
#    'ECONOMIC Keywords    [Support and Information]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'ECONOMIC Keywords    [Incentives]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Multi-level Legislation]',
#    'LEGAL Keywords    [Urban Landuse ]',
#    'LEGAL Keywords    [District Regulation]',
#    'LEGAL Keywords    [Participative Instruments]',
#    'LEGAL Keywords    [Energy Communities]',
#    'LEGAL Keywords    [Energy market structures]',
#    'LEGAL Keywords    [Innovative Institutional Change]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Narrative& Storytellung]',
#    'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#    'SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'SOCIAL Keywords    [Social Justice & Equity]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SOCIAL Keywords    [Cultural context]',
#    'SOCIAL Keywords    [Heritage]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'SPATIAL Keywords    [Governance Framework]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'PROCESSES & METHODS Keywords    [Scalability]',
#    'ENVIRONMENTAL Keywords    [Circularity]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'ENVIRONMENTAL Keywords    [Embodied energy]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Landscape]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'ENVIRONMENTAL Keywords    [Resilience]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Political Engagement]',
#    'POLITICAL Keywords    [Power Analysis]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Distributive Implications]',
#    'POLITICAL Keywords    [Regulation and Subsidies]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]',
#    'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#    'TECHNOLOGICAL Keywords    [Infrastructure]',
#    'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#    'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]'],
#   'deliverables': []},
#  {'name': 'PED4ALL',
#   'acronym': 'www.ped4all.eu',
#   'metadata': {'[Project Acronym]': 'PED4ALL',
#    '[URL to Project ressources]': 'www.ped4all.eu',
#    '[Project started in]': 2022,
#    '[Project duration]': '36 months',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': 'fabio.vanin@vub.be',
#    'Project description (Optional)': 'Positive energy districts (PEDs) are key tools to deliver the European Green Deal and climate targets by 2030. However, PEDs are often introverted islands in cities and the challenge is how to integrate them into their existing contexts creating climate-neutral, resilient and liveable neighbourhoods. Visions, plans, projects, and solutions for PEDs exist, but defining concrete, innovative, inclusive, and shared co-designed strategies for existing urban structures and societies, implementing and replicating them, remains in many cases the next urgent task.\nBuilding on the results of TRANS-PED, the aim of PED4ALL is to develop feasible, operative, implementable and inclusive strategies that can be adopted by PED and neighbourhood stakeholders to realise a deep energy transition and holistic changes to cities. This three-year project will engage an action-oriented network of PED and neighbourhood stakeholders in Belgium, Italy, and Turkey to apply a shared co-productive methodology to define a set of energy, policy and regulatory, governance and social, spatial, and design strategies for urban transition and innovation, to test and replicate them. The project partners will engage in a series of online and in-person activities to co-produce a range of practical tools to build a community of practice and position Europe as a global role model for urban energy transformations.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Market]',
#    'ECONOMIC Keywords    [Financial Strategies]',
#    'ECONOMIC Keywords    [Circular Economy]',
#    'ECONOMIC Keywords    [Cost Analysis]',
#    'ECONOMIC Keywords    [Affordability]',
#    'ECONOMIC Keywords    [Support and Information]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'ECONOMIC Keywords    [Incentives]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Multi-level Legislation]',
#    'LEGAL Keywords    [Urban Landuse ]',
#    'LEGAL Keywords    [District Regulation]',
#    'LEGAL Keywords    [Participative Instruments]',
#    'LEGAL Keywords    [Energy Communities]',
#    'LEGAL Keywords    [Energy market structures]',
#    'LEGAL Keywords    [Innovative Institutional Change]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Narrative& Storytellung]',
#    'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#    'SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'SOCIAL Keywords    [Social Justice & Equity]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SOCIAL Keywords    [Cultural context]',
#    'SOCIAL Keywords    [Heritage]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'SPATIAL Keywords    [Governance Framework]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'PROCESSES & METHODS Keywords    [Scalability]',
#    'ENVIRONMENTAL Keywords    [Circularity]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'ENVIRONMENTAL Keywords    [Embodied energy]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Landscape]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'ENVIRONMENTAL Keywords    [Resilience]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Political Engagement]',
#    'POLITICAL Keywords    [Power Analysis]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Distributive Implications]',
#    'POLITICAL Keywords    [Regulation and Subsidies]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]',
#    'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#    'TECHNOLOGICAL Keywords    [Infrastructure]',
#    'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#    'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]'],
#   'deliverables': []},
#  {'name': 'INTERACT',
#   'acronym': 'https://www.ped-interact.eu/',
#   'metadata': {'[Project Acronym]': 'INTERACT',
#    '[URL to Project ressources]': 'https://www.ped-interact.eu/',
#    '[Project started in]': 2021,
#    '[Project duration]': '2 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'INTERACT – Integration of Innovative Technologies of Positive Energy Districts into a Holistic Architecture – is an international research and innovation project with a cross-sectional collaboration between academia, municipalities, and businesses with participants from Austria, the Czech Republic, and Sweden.\n\nINTERACT boosts the emergence of Energy Communities as one crucial building block to achieve Positive Energy Districts. The project will design an optimal organization and structure for Energy Communities based on:\n\na. success-factors from a competence-network of existing PED/PEN approaches,\nb. stakeholder needs and motivation,\nc. the available technologies, and\nd. a holistic architecture.\n\nThe project will develop a roadmap for the Energy Community’s secure and reliable embedding into the power system structure, focusing on two pilot regions in Sweden and Austria.\n\nINTERACT is supported by the Austrian Ministry of Climate Action, Environment, Energy, Mobility, Innovation, and Technology (BMK), Technology Agency of the Czech Republic (TAČR) and Swedish Energy Agency / Viable Cities, Sweden. It has received funding in the framework of the PED Programme, which is implemented by the Joint Programming Initiative Urban Europe and SET Plan Action 3.2.\n\nThe project has been selected for funding in Positive Energy Districts (PEDs) pilot call JPI Urban Europe and is planned for 24 months with start in February 2021.',
#    'ECONOMIC Keywords    [Market]': 'Yes'},
#   'keywords': ['ECONOMIC Keywords    [Market]',
#    'ECONOMIC Keywords    [Financial Strategies]',
#    'ECONOMIC Keywords    [Circular Economy]',
#    'ECONOMIC Keywords    [Cost Analysis]',
#    'ECONOMIC Keywords    [Affordability]',
#    'ECONOMIC Keywords    [Support and Information]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'ECONOMIC Keywords    [Incentives]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Multi-level Legislation]',
#    'LEGAL Keywords    [Urban Landuse ]',
#    'LEGAL Keywords    [District Regulation]',
#    'LEGAL Keywords    [Participative Instruments]',
#    'LEGAL Keywords    [Energy Communities]',
#    'LEGAL Keywords    [Energy market structures]',
#    'LEGAL Keywords    [Innovative Institutional Change]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Narrative& Storytellung]',
#    'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#    'SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'SOCIAL Keywords    [Social Justice & Equity]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SOCIAL Keywords    [Cultural context]',
#    'SOCIAL Keywords    [Heritage]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'SPATIAL Keywords    [Governance Framework]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'PROCESSES & METHODS Keywords    [Scalability]',
#    'ENVIRONMENTAL Keywords    [Circularity]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'ENVIRONMENTAL Keywords    [Embodied energy]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Landscape]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'ENVIRONMENTAL Keywords    [Resilience]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Political Engagement]',
#    'POLITICAL Keywords    [Power Analysis]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Distributive Implications]',
#    'POLITICAL Keywords    [Regulation and Subsidies]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]',
#    'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#    'TECHNOLOGICAL Keywords    [Infrastructure]',
#    'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#    'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]'],
#   'deliverables': [{'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/01/Deliverable-2.2-Stakeholder-Needs-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/02/D2.3-Success-factors_v9_20220129_final-version.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2021/07/D3.1-.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'Yes'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 1]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/09/D3.3-LINK-ICT-_2022-08-31-vfinal4.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 1]',
#      'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 2]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/06/D-4.1-Design-of-the-Energy-Community-Organization-according-to-the-LINK-Solution-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/07/D-4.2-Use-Cases-for-the-integration-of-the-existing-innovative-technologies-with-the-LINK-solution_vFinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 1]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/11/D-4.3-Market-structure-and-its-interfaces-with-the-Energy-Community_vfinal2.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'Yes'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/05/D.5.1.-Current-regulatory-framework_20220430_final.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
# ...
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2022/10/Cities4PEDs-WP3-FINAL.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2022/10/Cities4PEDs-WP4-FINAL.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [Title of Deliverable (without numberering)]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2023/05/Cities4PEDs-WP6-Monitoring_FINAL_WithCover-1.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Financial Strategies]',
#      'ECONOMIC Keywords    [Circular Economy]',
#      'ECONOMIC Keywords    [Cost Analysis]',
#      'ECONOMIC Keywords    [Affordability]',
#      'ECONOMIC Keywords    [Support and Information]',
#      'ECONOMIC Keywords    [Ownership Structures]',
#      'ECONOMIC Keywords    [Incentives]',
#      'ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [Urban Landuse ]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'LEGAL Keywords    [Energy Communities]',
#      'LEGAL Keywords    [Energy market structures]',
#      'LEGAL Keywords    [Innovative Institutional Change]',
#      'SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Wellbeing & quality of life]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Justice & Equity]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'SOCIAL Keywords    [Heritage]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Mobility]',
#      'SPATIAL Keywords    [PED boundaries]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]',
#      'PROCESSES & METHODS Keywords    [Scalability]',
#      'ENVIRONMENTAL Keywords    [Circularity]',
#      'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#      'ENVIRONMENTAL Keywords    [Energy efficiency]',
#      'ENVIRONMENTAL Keywords    [Embodied energy]',
#      'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#      'ENVIRONMENTAL Keywords    [Landscape]',
#      'ENVIRONMENTAL Keywords    [Resource efficiency]',
#      'ENVIRONMENTAL Keywords    [Primary energy balance]',
#      'ENVIRONMENTAL Keywords    [Resilience]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]',
#      'POLITICAL Keywords    [Power Analysis]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Distributive Implications]',
#      'POLITICAL Keywords    [Regulation and Subsidies]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#      'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]',
#      'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]',
#      'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]']}]},
#  {'name': 'FLEXPOSTS',
#   'acronym': 'https://greenhubdenmark.dk/projekter/flexposts/',
#   'metadata': {'[Project Acronym]': 'FLEXPOSTS',
#    '[URL to Project ressources]': 'https://greenhubdenmark.dk/projekter/flexposts/',
#    '[Project started in]': '23-08-2022',
#    '[Project duration]': '3 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'Positive Energy Districts (PEDs) are areas with a net positive energy balance annually. These districts are crucial \nin the energy transition, but implementing them is difficult because of organisational, regulatory and planning \nissues. FLEXPOSTS aims to improve the implementation process of PEDs, focusing on flexible energy assets. This \nintegrates PEDs into urban planning and energy system planning. Organisational structures are developed and \nassessed, providing decision-makers the toolkit for implementation. FLEXPOSTS puts findings into practice in two \ndemonstration districts in Leeuwarden (NL) and Aalborg (DK), establishing a PED network with relevant \nstakeholders, business models, and strategies for facilitating development of PEDs.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Market]',
#    'ECONOMIC Keywords    [Financial Strategies]',
#    'ECONOMIC Keywords    [Circular Economy]',
#    'ECONOMIC Keywords    [Cost Analysis]',
#    'ECONOMIC Keywords    [Affordability]',
#    'ECONOMIC Keywords    [Support and Information]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'ECONOMIC Keywords    [Incentives]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Multi-level Legislation]',
#    'LEGAL Keywords    [Urban Landuse ]',
#    'LEGAL Keywords    [District Regulation]',
#    'LEGAL Keywords    [Participative Instruments]',
#    'LEGAL Keywords    [Energy Communities]',
#    'LEGAL Keywords    [Energy market structures]',
#    'LEGAL Keywords    [Innovative Institutional Change]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Narrative& Storytellung]',
#    'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#    'SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'SOCIAL Keywords    [Social Justice & Equity]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SOCIAL Keywords    [Cultural context]',
#    'SOCIAL Keywords    [Heritage]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'SPATIAL Keywords    [Governance Framework]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'PROCESSES & METHODS Keywords    [Scalability]',
#    'ENVIRONMENTAL Keywords    [Circularity]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'ENVIRONMENTAL Keywords    [Embodied energy]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Landscape]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'ENVIRONMENTAL Keywords    [Resilience]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Political Engagement]',
#    'POLITICAL Keywords    [Power Analysis]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Distributive Implications]',
#    'POLITICAL Keywords    [Regulation and Subsidies]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]',
#    'TECHNOLOGICAL Keywords    [Conversion & Storage]',
#    'TECHNOLOGICAL Keywords    [Infrastructure]',
#    'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]',
#    'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 1]',
#    'OTHER  If none of the keywords above apply, you can specify up to three additional keywords below:  [Keyword 2]'],
#   'deliverables': []}]

# %%
import pandas as pd
# Definition der korrekten Bereiche (basierend auf Benutzerinfo)
meta_rows = range(7, 14)             # Projekt-Metadaten: Zeile 8–14 (Index 7–13)
project_kw_rows = range(13, 76)      # Projekt-Keywords: Zeile 14–76 (Index 13–75)
deliverable_meta_rows = 3           # Immer 3 Metazeilen pro Deliverable
deliverable_kw_rows = 61            # Danach 61 Zeilen mit Keywords
first_deliverable_start = 76        # Erste Deliverable beginnt in Zeile 77 (Index 76)

# Extraktions-Funktion
def extract_projects_for_visualization(df):
    projects_data = []
    for col, colname in enumerate(df.columns[1:]):  # Spalte 0 enthält Fragen
        col+=1
        project = {}

        # Projekt-Metadaten
        meta_keys = df.iloc[meta_rows, 0].values
        meta_vals = df.iloc[meta_rows, col].values
        project["name"] = df.iloc[7, col]  # [Project Name]
        project["acronym"] = df.iloc[8, col]  # [Project Acronym]
        project["metadata"] = dict(zip(meta_keys, meta_vals))

        # Projekt-Keywords
        kw_labels = df.iloc[project_kw_rows, 0].values
        kw_values = df.iloc[project_kw_rows, col].fillna("").astype(str).values
        project_keywords = [kw for kw, val in zip(kw_labels, kw_values) if val.strip().lower() == "yes"]
        project["keywords"] = project_keywords

        # Deliverables
        deliverables = []
        row = first_deliverable_start
        while row + deliverable_meta_rows + deliverable_kw_rows <= df.shape[0]:
            # Metadaten
            d_meta_keys = df.iloc[row:row+deliverable_meta_rows, 0].values
            d_meta_vals = df.iloc[row:row+deliverable_meta_rows, col].values
            if pd.isna(d_meta_vals[0]) or d_meta_vals[0] == "":
                break  # kein weiteres Deliverable
            d_metadata = dict(zip(d_meta_keys, d_meta_vals))

            # Keywords
            d_kw_labels = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, 0].values
            d_kw_values = df.iloc[row+deliverable_meta_rows:row+deliverable_meta_rows+deliverable_kw_rows, col].fillna("").astype(str).values
            d_keywords = [kw for kw, val in zip(d_kw_labels, d_kw_values) if val.strip().lower() == "yes"]

            deliverables.append({
                "metadata": d_metadata,
                "keywords": d_keywords
            })

            row += deliverable_meta_rows + deliverable_kw_rows  # Nächster Block

        project["deliverables"] = deliverables
        projects_data.append(project)

    return projects_data



if __name__ == "__main__":
    # Anwendung der Funktion
    df = pd.read_excel("results2.xlsx")
    p = extract_projects_for_visualization(df)

    # Vorschau
    p[0]

# %%
p
# Out:
# [{'name': 'PED-ACT',
#   'acronym': 'https://ped-act.com/',
#   'metadata': {'[Project Acronym]': 'PED-ACT',
#    '[URL to Project ressources]': 'https://ped-act.com/',
#    '[Project started in]': '10/22',
#    '[Project duration]': '08/2025',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': 'xza@du.se   (project coordinator  Xing Xing Zhang)',
#    'Project description (Optional)': 'Positive Energy District (PED) is graded as an essential component towards climate neutrality and smart cities. The development of PED brings great needs in new processes and the related cooperation among stakeholders. This project (‘PED-ACT’) aims to optimise the process iteratively of PED development for enhanced stakeholder cooperation and reinforced decision-making.\nPED-ACT extracts the main characterization of PEDs automatically by machine learning approaches, through standardisation of the common database for existing PEDs, by focusing on Sweden, Turkey, and Austria. The digital PED references are then generated, based on a multi-criteria characterization matrix, by auto-matching the development needs/priorities from different stakeholders during bilateral learning and co-design processes among four specific cities (Borlänge, Umea, Karsiyaka-Izmir, Ankara) and a county (Lower Austria). PED-ACT finally evaluates the feasibility of these digital PED references to further develop the replication/upscaling plans, towards ‘climate-neutrality and smart cities’ goals.\nPED-ACT deeply learns a wealth of information from the existing PEDs and then maps the practical needs for PED development in local contexts iteratively. It leads to concrete cooperation from the outset with support of data and involvement of stakeholders. The project results will reinforce decision-making of PEDs and support public administrators/local stakeholders in the new pathways and development.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Cost Analysis]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Multi-level Legislation]',
#    'LEGAL Keywords    [Urban Landuse ]',
#    'LEGAL Keywords    [District Regulation]',
#    'LEGAL Keywords    [Participative Instruments]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'SPATIAL Keywords    [Governance Framework]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'PROCESSES & METHODS Keywords    [Scalability]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Power Analysis]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]'],
#   'deliverables': []},
#  {'name': 'PROPEL',
#   'acronym': 'https://sites.google.com/view/propel-ped/home-page?authuser=0',
#   'metadata': {'[Project Acronym]': 'PROPEL',
#    '[URL to Project ressources]': 'https://sites.google.com/view/propel-ped/home-page?authuser=0',
#    '[Project started in]': 2022,
#    '[Project duration]': '3 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': 'nicolas.caballero@eurac.edu',
#    'Project description (Optional)': 'The overall project goal is to demonstrate and assess methods to improve viability in PEDs by technological and societal innovation in urban agriculture, green/waste management, and transport. Including new innovative components into PEDs enables resilient energy supply to the system of urban systems, including urban-rural\nrelationships and transports within this system, by developing ethic business models based on circularity of resources and social innovation. The innovative edge is the inclusion of innovative PED components and improving possibilities for off-grid operation to increase the robustness and viability of PEDs, utilizing viable business models and innovative types of energy carriers via recycling of energy in the food-feed system, biogas and including transports in the PED system of systems. The innovative components that are included into PEDs are other types of energy carriers, via the food system of an urban system, while providing ecosystem services (e.g. closing nutrient cycles ensuring food security, mitigating climate change), improving the liveability in urban areas, and harmonize the urban-rural relationship in Sweden, Turkey and Italy.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Circular Economy]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Energy Communities]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'ENVIRONMENTAL Keywords    [Circularity]',
#    'ENVIRONMENTAL Keywords    [Climate adaptation/Climate neutral]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]',
#    'TECHNOLOGICAL Keywords    [Conversion & Storage]'],
#   'deliverables': []},
#  {'name': 'PED4ALL',
#   'acronym': 'www.ped4all.eu',
#   'metadata': {'[Project Acronym]': 'PED4ALL',
#    '[URL to Project ressources]': 'www.ped4all.eu',
#    '[Project started in]': 2022,
#    '[Project duration]': '36 months',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': 'fabio.vanin@vub.be',
#    'Project description (Optional)': 'Positive energy districts (PEDs) are key tools to deliver the European Green Deal and climate targets by 2030. However, PEDs are often introverted islands in cities and the challenge is how to integrate them into their existing contexts creating climate-neutral, resilient and liveable neighbourhoods. Visions, plans, projects, and solutions for PEDs exist, but defining concrete, innovative, inclusive, and shared co-designed strategies for existing urban structures and societies, implementing and replicating them, remains in many cases the next urgent task.\nBuilding on the results of TRANS-PED, the aim of PED4ALL is to develop feasible, operative, implementable and inclusive strategies that can be adopted by PED and neighbourhood stakeholders to realise a deep energy transition and holistic changes to cities. This three-year project will engage an action-oriented network of PED and neighbourhood stakeholders in Belgium, Italy, and Turkey to apply a shared co-productive methodology to define a set of energy, policy and regulatory, governance and social, spatial, and design strategies for urban transition and innovation, to test and replicate them. The project partners will engage in a series of online and in-person activities to co-produce a range of practical tools to build a community of practice and position Europe as a global role model for urban energy transformations.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Affordability]',
#    'ECONOMIC Keywords    [Ownership Structures]',
#    'LEGAL Keywords    [Energy Communities]',
#    'LEGAL Keywords    [Innovative Institutional Change]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#    'SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Social Justice & Equity]',
#    'SOCIAL Keywords    [Cultural context]',
#    'SPATIAL Keywords    [Urban planning tools/instruments]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'ENVIRONMENTAL Keywords    [Resource efficiency]',
#    'ENVIRONMENTAL Keywords    [Resilience]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Distributive Implications]'],
#   'deliverables': []},
#  {'name': 'INTERACT',
#   'acronym': 'https://www.ped-interact.eu/',
#   'metadata': {'[Project Acronym]': 'INTERACT',
#    '[URL to Project ressources]': 'https://www.ped-interact.eu/',
#    '[Project started in]': 2021,
#    '[Project duration]': '2 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'INTERACT – Integration of Innovative Technologies of Positive Energy Districts into a Holistic Architecture – is an international research and innovation project with a cross-sectional collaboration between academia, municipalities, and businesses with participants from Austria, the Czech Republic, and Sweden.\n\nINTERACT boosts the emergence of Energy Communities as one crucial building block to achieve Positive Energy Districts. The project will design an optimal organization and structure for Energy Communities based on:\n\na. success-factors from a competence-network of existing PED/PEN approaches,\nb. stakeholder needs and motivation,\nc. the available technologies, and\nd. a holistic architecture.\n\nThe project will develop a roadmap for the Energy Community’s secure and reliable embedding into the power system structure, focusing on two pilot regions in Sweden and Austria.\n\nINTERACT is supported by the Austrian Ministry of Climate Action, Environment, Energy, Mobility, Innovation, and Technology (BMK), Technology Agency of the Czech Republic (TAČR) and Swedish Energy Agency / Viable Cities, Sweden. It has received funding in the framework of the PED Programme, which is implemented by the Joint Programming Initiative Urban Europe and SET Plan Action 3.2.\n\nThe project has been selected for funding in Positive Energy Districts (PEDs) pilot call JPI Urban Europe and is planned for 24 months with start in February 2021.',
#    'ECONOMIC Keywords    [Market]': 'Yes'},
#   'keywords': ['ECONOMIC Keywords    [Market]',
#    'ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Energy Communities]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Behavioural Change & Awareness]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Infrastructure]'],
#   'deliverables': [{'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/01/Deliverable-2.2-Stakeholder-Needs-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'SOCIAL Keywords    [Social Innovation]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/02/D2.3-Success-factors_v9_20220129_final-version.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['LEGAL Keywords    [Energy Communities]',
#      'SOCIAL Keywords    [Community Engagement]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2021/07/D3.1-.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'Yes'},
#     'keywords': ['LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Energy market structures]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/09/D3.3-LINK-ICT-_2022-08-31-vfinal4.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'TECHNOLOGICAL Keywords    [Infstrastructure]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/06/D-4.1-Design-of-the-Energy-Community-Organization-according-to-the-LINK-Solution-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Ownership Structures]',
#      'LEGAL Keywords    [Energy Communities]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/07/D-4.2-Use-Cases-for-the-integration-of-the-existing-innovative-technologies-with-the-LINK-solution_vFinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['LEGAL Keywords    [Energy Communities]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/11/D-4.3-Market-structure-and-its-interfaces-with-the-Energy-Community_vfinal2.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'Yes'},
#     'keywords': ['LEGAL Keywords    [Energy Communities]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/05/D.5.1.-Current-regulatory-framework_20220430_final.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['LEGAL Keywords    [District Regulation]',
#      'POLITICAL Keywords    [Regulation and Subsidies]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://www.ped-interact.eu/wp-content/uploads/2022/09/D5_2_Business-cases-for-INTERACT-Energy-Communities-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['ECONOMIC Keywords    [Business models]',
#      'LEGAL Keywords    [Energy Communities]']}]},
#  {'name': 'SimplyPositive',
#   'acronym': 'http://simplypositive.eu/',
#   'metadata': {'[Project Acronym]': 'SimplyPositive',
#    '[URL to Project ressources]': 'http://simplypositive.eu/',
#    '[Project started in]': 2023,
#    '[Project duration]': '2 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'SIMPLY POSITIVE supports the emergence of Positive Energy Districts and the transition to Climate Neutral Cities. On the example of four focus districts from different European Countries we will establish and test strategies how to tackle the necessary energy transition. We will analyze different areas which were selected as important by the focus districts:\n\n·       Photo voltaic solar panels (PV) maximization,\n\n·       integration of electric vehicles in mobility concepts and usage as energy storage,\n\n·       usage patterns to increase energy efficiency and\n\n·       common climate and energy action plans.\n\nBased on a common Positive energy district definition framework for existing urban districts we will show how to best monitor and visualize achieved results. Fitting participation concepts shall ensure active stakeholder participation and motivate further cities to join the pathway towards reaching 1000s of Positive Energy Districts and Positive Energy Neighborhoods all over Europe.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['SPATIAL Keywords    [Mobility]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'ENVIRONMENTAL Keywords    [Energy efficiency]',
#    'TECHNOLOGICAL Keywords    [Local Renewable Production]',
#    'TECHNOLOGICAL Keywords    [Energy Savings]'],
#   'deliverables': [{'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2023/12/D3.1-Framework-definition-status-and-Methodology-description-for-SimplyPositive-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SPATIAL Keywords    [PED boundaries]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/12/D4.1_Geospatial-map-and-report-on-geo-referenced-multi-layer-mapping-of-the-PV-potential-on-the-example-of-Focus-District-of-Amsterdam-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [Strategic planning]',
#      'TECHNOLOGICAL Keywords    [Local Renewable Production]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/09/D4.2-Report-on-Urban-Policy-Suggestions-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'POLITICAL Keywords    [Decision Support Tools]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/09/D4.3-Feasibility-study-on-e-mobility-support-through-local-DERs-with-expected-impact-on-grid-level.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SPATIAL Keywords    [Mobility]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/12/D4.4-Demand-side-actions-of-residents-to-reduce-energy-consumption-and-carbon-footprint-in-focus-districts_final.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Everyday Consumption & Production Practices]',
#      'SOCIAL Keywords    [Behavioural Change & Awareness]',
#      'TECHNOLOGICAL Keywords    [Energy Savings]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/11/D4.6-Guidelines-on-how-to-use-the-SECAP-methodology-vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SPATIAL Keywords    [Strategic planning]',
#      'PROCESSES & METHODS Keywords    [Monitoring]',
#      'POLITICAL Keywords    [City Missions]',
#      'POLITICAL Keywords    [Decision Support Tools]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/06/SIMPLY-POSITIVE_D5.1_Target-Action-Plan_vfinal.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['POLITICAL Keywords    [Decision Support Tools]',
#      'POLITICAL Keywords    [Political Engagement]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/ped_monitoring_tool/',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['PROCESSES & METHODS Keywords    [Monitoring]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'http://simplypositive.eu/wp-content/uploads/2024/11/T-6.4-Local-Authorities-Policies-to-Support-Positive-Energy-Districts-.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['LEGAL Keywords    [Multi-level Legislation]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Regulation and Subsidies]']}]},
#  {'name': 'TRANS-PED',
#   'acronym': 'https://trans-ped.eu/results/',
#   'metadata': {'[Project Acronym]': 'TRANS-PED',
#    '[URL to Project ressources]': 'https://trans-ped.eu/results/',
#    '[Project started in]': 2021,
#    '[Project duration]': 2,
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'Trans-PED was a 2-year pilot project to advance the governance approach for positive energy district stakeholders to better realise deep changes to their cities. Trans-PED was an international project involving 11 partners from Austria, Belgium, and Sweden, led by KTH Royal institute of Technology and co-funded by JPI Urban Europe. The team has been developing advancements for the governance approach through collaboration with five established and aspirational PEDs.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['SOCIAL Keywords    [Wellbeing & quality of life]',
#    'SOCIAL Keywords    [Social Innovation]',
#    'SOCIAL Keywords    [Cultural context]'],
#   'deliverables': [{'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/wp-content/uploads/2024/01/Up-scaling-PEDs.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['PROCESSES & METHODS Keywords    [Scalability]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/wp-content/uploads/2024/01/Transped_Transversal-Analysis.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/wp-content/uploads/2024/01/Transped_Catalogue-of-PED-Assessment-Parameters.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': []},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/wp-content/uploads/2024/01/PED-Assessment-Toolbox.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['PROCESSES & METHODS Keywords    [Monitoring]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/toolbox/',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Community Engagement]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/wp-content/uploads/2023/05/Report_on_Responsible_Innovation_in_PED.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Social Innovation]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://trans-ped.eu/wp-content/uploads/2023/05/Responsible_Innovation_in_and_for_PEDs.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Social Innovation]']}]},
#  {'name': 'Cities4PEDs',
#   'acronym': 'https://energy-cities.eu/project/cities4peds-resources/',
#   'metadata': {'[Project Acronym]': 'Cities4PEDs',
#    '[URL to Project ressources]': 'https://energy-cities.eu/project/cities4peds-resources/',
#    '[Project started in]': 2021,
#    '[Project duration]': '2 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'Exploring city levers to enable Positive Energy Districts (PEDs) across diverging contexts',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Ownership Structures]',
#    'SOCIAL Keywords    [Community Engagement]',
#    'SOCIAL Keywords    [Narrative& Storytellung]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [District/neighbourhoods typologies]',
#    'SPATIAL Keywords    [PED boundaries]',
#    'PROCESSES & METHODS Keywords    [Co-Creation]',
#    'PROCESSES & METHODS Keywords    [Monitoring]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'POLITICAL Keywords    [City Missions]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'POLITICAL Keywords    [Governance Structure]',
#    'POLITICAL Keywords    [Regulation and Subsidies]'],
#   'deliverables': [{'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2023/07/Cities4PEDs-WP2-Definition-.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SPATIAL Keywords    [PED boundaries]',
#      'PROCESSES & METHODS Keywords    [Simulation]',
#      'PROCESSES & METHODS Keywords    [Modeling Tools]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2021/11/Cities4PEDs-Atlas-Nov.-2021.pdf.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': 'For a city to embark on developing a Positive Energy District (PED), the framework conditions, such as political mandate, legal, financial and organisational structures, etc. will have to be in place or established over time. The Cities4PEDs project has investigated the framework conditions for developing PEDs in three cities, Brussels, Stockholm and Vienna and further interesting PED-relevant projects across Europe.  Twenty-five PED-relevant projects were identified by the consortium for further investigation. Out of this list, seven projects were selected for in-depth interviews based on their holistic approach to sustainability at large but in particular, their relevance from a PED perspective. The investigations have been analysed and a multidisciplinary overview of the different aspects of concern for the realization of PEDs has been developed. This PED Atlas is a documentation of the process, the known framework conditions and PED elements.',
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['LEGAL Keywords    [Multi-level Legislation]',
#      'LEGAL Keywords    [District Regulation]',
#      'LEGAL Keywords    [Participative Instruments]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'SPATIAL Keywords    [District/neighbourhoods typologies]',
#      'SPATIAL Keywords    [Governance Framework]',
#      'POLITICAL Keywords    [Governance Structure]',
#      'POLITICAL Keywords    [Regulation and Subsidies]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2022/10/Cities4PEDs-WP3-FINAL.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['LEGAL Keywords    [District Regulation]',
#      'SPATIAL Keywords    [Urban planning tools/instruments]',
#      'POLITICAL Keywords    [City Missions]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2022/10/Cities4PEDs-WP4-FINAL.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['SOCIAL Keywords    [Community Engagement]',
#      'SOCIAL Keywords    [Narrative& Storytellung]',
#      'SOCIAL Keywords    [Social Innovation]',
#      'SOCIAL Keywords    [Cultural ontext]',
#      'PROCESSES & METHODS Keywords    [Co-Creation]']},
#    {'metadata': {'Please provide general information about your project deliverable.\xa0  \xa0  [URL of Deliverable (if available)]': 'https://energy-cities.eu/wp-content/uploads/2023/05/Cities4PEDs-WP6-Monitoring_FINAL_WithCover-1.pdf',
#      'Please provide general information about your project deliverable.\xa0  \xa0  [(optional) Content of deliverable]': nan,
#      'ECONOMIC Keywords    [Market]': 'No'},
#     'keywords': ['PROCESSES & METHODS Keywords    [Monitoring]']}]},
#  {'name': 'FLEXPOSTS',
#   'acronym': 'https://greenhubdenmark.dk/projekter/flexposts/',
#   'metadata': {'[Project Acronym]': 'FLEXPOSTS',
#    '[URL to Project ressources]': 'https://greenhubdenmark.dk/projekter/flexposts/',
#    '[Project started in]': '23-08-2022',
#    '[Project duration]': '3 years',
#    '[Contact (optional email for inquiries about representing the project in the PED landscape) ]': nan,
#    'Project description (Optional)': 'Positive Energy Districts (PEDs) are areas with a net positive energy balance annually. These districts are crucial \nin the energy transition, but implementing them is difficult because of organisational, regulatory and planning \nissues. FLEXPOSTS aims to improve the implementation process of PEDs, focusing on flexible energy assets. This \nintegrates PEDs into urban planning and energy system planning. Organisational structures are developed and \nassessed, providing decision-makers the toolkit for implementation. FLEXPOSTS puts findings into practice in two \ndemonstration districts in Leeuwarden (NL) and Aalborg (DK), establishing a PED network with relevant \nstakeholders, business models, and strategies for facilitating development of PEDs.',
#    'ECONOMIC Keywords    [Market]': 'No'},
#   'keywords': ['ECONOMIC Keywords    [Business models]',
#    'LEGAL Keywords    [Energy market structures]',
#    'SOCIAL Keywords    [Policy]',
#    'SPATIAL Keywords    [Strategic planning]',
#    'PROCESSES & METHODS Keywords    [Simulation]',
#    'PROCESSES & METHODS Keywords    [Modeling Tools]',
#    'ENVIRONMENTAL Keywords    [Green house gas emissions]',
#    'ENVIRONMENTAL Keywords    [Primary energy balance]',
#    'POLITICAL Keywords    [Decision Support Tools]',
#    'TECHNOLOGICAL Keywords    [Balanced Demand & Supply]',
#    'TECHNOLOGICAL Keywords    [Multi-commodity energy systems]'],
#   'deliverables': []}]

# %%
p["keywords"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 p["keywords"]
#
# TypeError: list indices must be integers or slices, not str
